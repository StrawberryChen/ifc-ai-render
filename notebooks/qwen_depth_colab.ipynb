# %% [markdown]
# # IFC Depth -> Qwen-Image
# 在 Colab 中选择 **A100 GPU** 后按顺序运行。首次下载模型会比较久。

# %%
# !nvidia-smi
import torch
assert torch.cuda.is_available(), '请先在运行时设置中启用GPU'
print(torch.cuda.get_device_name(0))

# %% [markdown]
# ## 获取项目
# 公开仓库可直接 clone。私有仓库请在 Colab Secrets 新建 `GITHUB_TOKEN`，并授予该仓库只读权限。

# %%
import os, subprocess
from pathlib import Path
repo = Path('/content/ifc-ai-render')
if not repo.exists():
    try:
        from google.colab import userdata
        token = userdata.get('GITHUB_TOKEN')
    except Exception:
        token = None
    url = 'https://github.com/StrawberryChen/ifc-ai-render.git'
    if token:
        url = f'https://x-access-token:{token}@github.com/StrawberryChen/ifc-ai-render.git'
    subprocess.run(['git', 'clone', url, str(repo)], check=True, stdout=subprocess.DEVNULL)
os.chdir(repo)
print(repo)

# %%
DIFFSYNTH_COMMIT = 'b1c02ce76aabc989f6bf534756b2da84532249e5'
# !pip -q install -r requirements-colab.txt
# !pip -q install "git+https://github.com/modelscope/DiffSynth-Studio.git@$DIFFSYNTH_COMMIT"

# %% [markdown]
# ## 生成
# 第一次先使用仓库示例深度图。跑通后，把 `DEPTH` 改成你上传到 Colab/Drive 的深度图路径。

# %%
DEPTH = 'data/examples/Building-Architecture.depth.png'
OUTPUT = '/content/building-result.png'
PROMPT = '当代低层公共建筑，严格保持输入建筑的体量、屋顶轮廓、门窗位置和透视关系，深灰色清水混凝土，大面积落地玻璃，细黑色金属窗框，专业建筑摄影，阴天柔光，真实材质，周边简洁景观，高细节'
# !python inference/generate_qwen_depth.py --depth "$DEPTH" --prompt "$PROMPT" --output "$OUTPUT" --seed 0

# %%
from IPython.display import display
from PIL import Image
display(Image.open(OUTPUT))
